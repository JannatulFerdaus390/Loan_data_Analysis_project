# %%
import pandas as pd
data = pd.read_csv(r"loan_data.csv")
data
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %% [markdown]
# # .head
# (Shows the first N rows of the data, N=5)

# %%
data.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %% [markdown]
# # .shape
# (Shows total number of rows and columns)

# %%
data.shape
# Out:
# (9578, 14)

# %% [markdown]
# # .index
# (Provides the index of the dataframe)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=9578, step=1)

# %% [markdown]
# # .columns
# (Shows the name of each column)

# %%
data.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %% [markdown]
# # .dtypes
# (shows the data types of each column)

# %%
data.dtypes
# Out:
# credit.policy          int64
# purpose               object
# int.rate             float64
# installment          float64
# log.annual.inc       float64
# dti                  float64
# fico                   int64
# days.with.cr.line    float64
# revol.bal              int64
# revol.util           float64
# inq.last.6mths         int64
# delinq.2yrs            int64
# pub.rec                int64
# not.fully.paid         int64
# dtype: object

# %% [markdown]
# # .unique()
# (shows the unique value of the single column only)

# %%
data["purpose"].unique()
# Out:
# array(['debt_consolidation', 'credit_card', 'all_other',
#        'home_improvement', 'small_business', 'major_purchase',
#        'educational'], dtype=object)

# %% [markdown]
# # .nunique()
# (shows the total number of unique values in the single column and also for whole dataframe)

# %%
data.nunique()
# Out:
# credit.policy           2
# purpose                 7
# int.rate              249
# installment          4788
# log.annual.inc       1987
# dti                  2529
# fico                   44
# days.with.cr.line    2687
# revol.bal            7869
# revol.util           1035
# inq.last.6mths         28
# delinq.2yrs            11
# pub.rec                 6
# not.fully.paid          2
# dtype: int64

# %% [markdown]
# # .count()
# shows the total number of non-null values of single column and also for whole dataframe

# %%
data.count()
# Out:
# credit.policy        9578
# purpose              9578
# int.rate             9578
# installment          9578
# log.annual.inc       9578
# dti                  9578
# fico                 9578
# days.with.cr.line    9578
# revol.bal            9578
# revol.util           9578
# inq.last.6mths       9578
# delinq.2yrs          9578
# pub.rec              9578
# not.fully.paid       9578
# dtype: int64

# %% [markdown]
# # .value_counts()
# shows all the unique values with their counts for the single column only

# %%
data["purpose"].value_counts()
# Out:
# purpose
# debt_consolidation    3957
# all_other             2331
# credit_card           1262
# home_improvement       629
# small_business         619
# major_purchase         437
# educational            343
# Name: count, dtype: int64

# %% [markdown]
# # .info()
# provides basic information about the dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# # Q1: Find all the unique "int.rate" values in the data.

# %%
#first way
data.nunique()
# Out:
# credit.policy           2
# purpose                 7
# int.rate              249
# installment          4788
# log.annual.inc       1987
# dti                  2529
# fico                   44
# days.with.cr.line    2687
# revol.bal            7869
# revol.util           1035
# inq.last.6mths         28
# delinq.2yrs            11
# pub.rec                 6
# not.fully.paid          2
# dtype: int64

# %%
#2nd way
data["int.rate"].nunique()
# Out:
# 249

# %%
#3rd way (total number is 249)
data["int.rate"].unique()
# Out:
# array([0.1189, 0.1071, 0.1357, 0.1008, 0.1426, 0.0788, 0.1496, 0.1114,
#        0.1134, 0.1221, 0.1347, 0.1324, 0.0859, 0.0714, 0.0863, 0.1103,
#        0.1317, 0.0894, 0.1039, 0.1513, 0.08  , 0.1355, 0.1229, 0.0901,
#        0.0743, 0.1375, 0.0807, 0.1028, 0.087 , 0.1122, 0.0996, 0.0933,
#        0.0838, 0.0775, 0.1059, 0.1596, 0.1154, 0.1343, 0.1249, 0.0964,
#        0.1186, 0.1501, 0.128 , 0.1091, 0.1217, 0.1533, 0.0712, 0.1438,
#        0.1565, 0.1467, 0.1312, 0.147 , 0.1407, 0.1014, 0.1046, 0.133 ,
#        0.0983, 0.1393, 0.092 , 0.1236, 0.1362, 0.1078, 0.1583, 0.1109,
#        0.1141, 0.1267, 0.1204, 0.0951, 0.1172, 0.1299, 0.1488, 0.152 ,
#        0.1425, 0.1836, 0.1615, 0.06  , 0.0832, 0.1261, 0.0945, 0.1197,
#        0.1387, 0.0976, 0.1292, 0.0737, 0.0768, 0.1166, 0.1418, 0.1545,
#        0.1482, 0.1703, 0.145 , 0.1671, 0.1576, 0.1608, 0.164 , 0.1734,
#        0.1051, 0.157 , 0.1222, 0.1273, 0.1379, 0.1253, 0.1128, 0.1286,
# ...

# %% [markdown]
# # Q2: Find the number of times when the purpose is "educational"

# %%
#using "value_counts()"
data.purpose.value_counts()
# Out:
# purpose
# debt_consolidation    3957
# all_other             2331
# credit_card           1262
# home_improvement       629
# small_business         619
# major_purchase         437
# educational            343
# Name: count, dtype: int64

# %%
#using filtering

data[data["purpose"] == "educational"]
# Out:
#       credit.policy      purpose  int.rate  installment  log.annual.inc  \
# 46                1  educational    0.0775       168.60        8.987197
# 53                1  educational    0.0996       112.87        9.510445
# 77                1  educational    0.0743       124.31       10.596635
# 115               1  educational    0.1059       195.27        9.852194
# 140               1  educational    0.1249       100.35       10.279181
# ...             ...          ...       ...          ...             ...
# 9439              0  educational    0.1600       527.36       11.070459
# 9468              0  educational    0.1461       168.93       10.578980
# 9498              0  educational    0.1426       267.59        9.878170
# 9505              0  educational    0.1287       121.08       10.085809
# 9547              0  educational    0.1607       147.82        9.862666
#
#         dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# ...

# %%
#using groupby
data.groupby("purpose").get_group("educational")
# Out:
#       credit.policy      purpose  int.rate  installment  log.annual.inc  \
# 46                1  educational    0.0775       168.60        8.987197
# 53                1  educational    0.0996       112.87        9.510445
# 77                1  educational    0.0743       124.31       10.596635
# 115               1  educational    0.1059       195.27        9.852194
# 140               1  educational    0.1249       100.35       10.279181
# ...             ...          ...       ...          ...             ...
# 9439              0  educational    0.1600       527.36       11.070459
# 9468              0  educational    0.1461       168.93       10.578980
# 9498              0  educational    0.1426       267.59        9.878170
# 9505              0  educational    0.1287       121.08       10.085809
# 9547              0  educational    0.1607       147.82        9.862666
#
#         dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# ...

# %% [markdown]
# # Q3: Find the number of times when the "inq.last.6mths" is exactly 3

# %%
data[data["inq.last.6mths"] == 3]
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 19                1      major_purchase    0.1513       173.65
# 37                1         credit_card    0.1122       164.23
# 58                1         credit_card    0.1249       401.37
# 72                1  debt_consolidation    0.0996       257.99
# 74                1    home_improvement    0.0964        80.26
# ...             ...                 ...       ...          ...
# 9089              0         educational    0.1221       333.15
# 9106              0  debt_consolidation    0.1411       239.61
# 9336              0         educational    0.0859       237.08
# 9393              0      small_business    0.1913       918.02
# 9415              0    home_improvement    0.1148       725.31
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 19         11.002100   2.74   667        1126.958333        591        84.4
# ...

# %% [markdown]
# # Q4: Find all the null values

# %%
#1st way
data.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
#2nd way
data.notnull().sum()
# Out:
# credit.policy        9578
# purpose              9578
# int.rate             9578
# installment          9578
# log.annual.inc       9578
# dti                  9578
# fico                 9578
# days.with.cr.line    9578
# revol.bal            9578
# revol.util           9578
# inq.last.6mths       9578
# delinq.2yrs          9578
# pub.rec              9578
# not.fully.paid       9578
# dtype: int64

# %% [markdown]
# # Q5: Rename the column name "purpose" to "loan_purpose"

# %%
data.rename(columns = {"purpose": "loan_purpose","log.annual.inc" : "log_annual_inc"}, inplace = True)
data.head()
# Out:
#    credit.policy        loan_purpose  int.rate  installment  log_annual_inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %% [markdown]
# # Q6: What is the mean value of "revol.bal"?

# %%
data["revol.bal"].mean()
# Out:
# 16913.963875548132

# %% [markdown]
# # Q7: What is the standard deviation of "installment"?

# %%
#data.installment.std()
data["installment"].std()
# Out:
# 207.07130149985852

# %% [markdown]
# # Q8: What is the Variance of "revol.util"?

# %%
data["revol.util"].var()
# Out:
# 841.8363918560797

# %% [markdown]
# # Q9: Find all instances when "credit" was recorded

# %%
#value_counts()
data["loan_purpose"].value_counts()
# Out:
# loan_purpose
# debt_consolidation    3957
# all_other             2331
# credit_card           1262
# home_improvement       629
# small_business         619
# major_purchase         437
# educational            343
# Name: count, dtype: int64

# %%
#str.contains

data[data["loan_purpose"].str.contains("credit")]
# Out:
#       credit.policy loan_purpose  int.rate  installment  log_annual_inc  \
# 1                 1  credit_card    0.1071       228.22       11.082143
# 4                 1  credit_card    0.1426       102.92       11.299732
# 5                 1  credit_card    0.0788       125.13       11.904968
# 17                1  credit_card    0.0894       476.58       11.608236
# 22                1  credit_card    0.1355       339.60       11.512925
# ...             ...          ...       ...          ...             ...
# 9526              0  credit_card    0.0788       437.93       11.820410
# 9530              0  credit_card    0.1099       425.56       11.571194
# 9538              0  credit_card    0.1422       244.28       11.561716
# 9557              0  credit_card    0.1025       466.35       12.206073
# 9559              0  credit_card    0.1273       688.11       11.314475
#
#         dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# ...

# %% [markdown]
# # Q10: Find all the instances when "fico is above 700" and "not.fully.paid is 1"

# %%
data[(data["fico"] > 700) & (data["not.fully.paid"] == 1)]
# Out:
#       credit.policy        loan_purpose  int.rate  installment  \
# 7                 1           all_other    0.1114       131.22
# 74                1    home_improvement    0.0964        80.26
# 76                1  debt_consolidation    0.1122       507.46
# 89                1      small_business    0.0964       642.02
# 102               1      small_business    0.1501        73.68
# ...             ...                 ...       ...          ...
# 9555              0    home_improvement    0.1311       674.90
# 9563              0  debt_consolidation    0.1099       556.50
# 9569              0    home_improvement    0.1426       823.34
# 9574              0           all_other    0.1253       257.70
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log_annual_inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 7          11.002100  11.08   722        5116.000000      24220        68.6
# ...

# %% [markdown]
# # Q11: What is the mean value of each column agains each "loan_purpose"

# %%
data.groupby("loan_purpose").mean()
# Out:
#                     credit.policy  int.rate  installment  log_annual_inc  \
# loan_purpose
# all_other                0.787216  0.116771   244.937542       10.845313
# credit_card              0.808241  0.119738   319.500713       11.047230
# debt_consolidation       0.814506  0.126595   358.984390       10.912909
# educational              0.740525  0.119907   217.547201       10.549956
# home_improvement         0.813990  0.117507   337.071590       11.201979
# major_purchase           0.848970  0.114171   243.483913       10.844895
# small_business           0.799677  0.138087   433.826607       11.146216
#
#                           dti        fico  days.with.cr.line     revol.bal  \
# loan_purpose
# all_other           11.079498  715.344058        4311.706153  12883.039897
# credit_card         14.099398  709.626783        4857.005943  23180.020602
# debt_consolidation  14.076462  703.871367        4533.037139  17146.710639
# ...

# %% [markdown]
# # Q12: What is the minimum and maximum value of each column against each "loan_purpose"

# %%
data.groupby("loan_purpose").min()
# Out:
#                     credit.policy  int.rate  installment  log_annual_inc  dti  \
# loan_purpose
# all_other                       0    0.0639        15.69        7.600902  0.0
# credit_card                     0    0.0600        16.73        8.922658  0.0
# debt_consolidation              0    0.0600        23.21        7.547502  0.0
# educational                     0    0.0600        15.67        8.101678  0.0
# home_improvement                0    0.0600        28.47        9.392662  0.0
# major_purchase                  0    0.0705        30.94        8.699515  0.0
# small_business                  0    0.0714        16.25        8.987197  0.0
#
#                     fico  days.with.cr.line  revol.bal  revol.util  \
# loan_purpose
# all_other            632         178.958333          0         0.0
# credit_card          627         183.041667          0         0.0
# debt_consolidation   612         180.041667          0         0.0
# ...

# %%
data.groupby("loan_purpose").max()
# Out:
#                     credit.policy  int.rate  installment  log_annual_inc  \
# loan_purpose
# all_other                       1    0.2164       916.95       13.997832
# credit_card                     1    0.2086       922.42       13.142166
# debt_consolidation              1    0.2121       940.14       14.528354
# educational                     1    0.2011       861.88       12.206073
# home_improvement                1    0.2164       902.06       13.487006
# major_purchase                  1    0.2017       898.55       14.180154
# small_business                  1    0.2121       926.83       13.331002
#
#                       dti  fico  days.with.cr.line  revol.bal  revol.util  \
# loan_purpose
# all_other           29.90   822        17639.95833     602519       108.8
# credit_card         29.95   812        17616.00000     394107       106.4
# debt_consolidation  29.96   822        16259.04167     290341       119.0
# ...

# %% [markdown]
# # Q13: Show all the records where "loan_purpose" is home_improvement

# %%
data[data["loan_purpose"] == "home_improvement"]
# Out:
#       credit.policy      loan_purpose  int.rate  installment  log_annual_inc  \
# 8                 1  home_improvement    0.1134        87.19       11.407565
# 32                1  home_improvement    0.0743       155.38       11.918391
# 33                1  home_improvement    0.0807        78.42       11.608236
# 39                1  home_improvement    0.0933       159.77       12.100712
# 40                1  home_improvement    0.0807       156.84       12.100712
# ...             ...               ...       ...          ...             ...
# 9549              0  home_improvement    0.2164       729.70       11.877569
# 9551              0  home_improvement    0.1348       508.87       11.736069
# 9555              0  home_improvement    0.1311       674.90       12.292250
# 9569              0  home_improvement    0.1426       823.34       12.429216
# 9576              0  home_improvement    0.1600       351.58       10.819778
#
# ...

# %% [markdown]
# # Q14: Find all instances when "loan_purposes is small_business" or "dti is above 15"

# %%
data[(data["loan_purpose"] == "small_business") | (data["dti"] > 15)].tail(50)
# Out:
#       credit.policy        loan_purpose  int.rate  installment  \
# 9482              0  debt_consolidation    0.1357       339.69
# 9485              0      major_purchase    0.1704       231.89
# 9491              0      small_business    0.1426       514.59
# 9494              0         credit_card    0.1183       480.45
# 9495              0      small_business    0.1531       870.39
# 9496              0      small_business    0.1635       169.58
# 9497              0           all_other    0.1183       331.34
# 9498              0         educational    0.1426       267.59
# 9499              0  debt_consolidation    0.1496       554.32
# 9501              0    home_improvement    0.1531        87.04
# 9502              0  debt_consolidation    0.1392       474.51
# 9506              0  debt_consolidation    0.1322       338.01
# 9507              0  debt_consolidation    0.1322       253.51
# 9509              0           all_other    0.1287        67.27
# ...

# %% [markdown]
# # Q15: Find all Instances when: a) loan_purpose is home_improvement and revol.bal > 300000  or b) days.with.cr.line > 6000

# %%
data[(data["loan_purpose"] == "home_improvement") & (data["revol.bal"] > 300000) | (data["days.with.cr.line"] > 6000)]
# Out:
#       credit.policy        loan_purpose  int.rate  installment  \
# 5                 1         credit_card    0.0788       125.13
# 10                1  debt_consolidation    0.1347       360.43
# 12                1  debt_consolidation    0.0859       316.11
# 15                1      major_purchase    0.1103       327.53
# 17                1         credit_card    0.0894       476.58
# ...             ...                 ...       ...          ...
# 9563              0  debt_consolidation    0.1099       556.50
# 9564              0           all_other    0.1385       511.56
# 9571              0           all_other    0.1568       161.01
# 9572              0  debt_consolidation    0.1565        69.98
# 9573              0           all_other    0.1461       344.76
#
#       log_annual_inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 5          11.904968  16.98   727        6120.041667      50807        51.0
# ...
